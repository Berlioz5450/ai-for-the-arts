# %% [markdown]
# Hello, World! the following code was created as my first attempt aat programming in this course to help me understand how to write and run code in GitHub codespaces.

# %%
print ("Hello, World")
# Out:
# Hello, World

# %% [markdown]
# Learning basic programming concepts
# *would like to acheive minimal undertanding of programming and the coding process

# %% [markdown]
# Copilot coding printing experiment:
# By putting the initial 'hello world' promt into copilot, it broke down the concept of printing and provided a step-by-step example of the code.
# *PRINT is a built in function in Python, it is telling the computer to display something on the screen.
# *"Hello, world" is a *String*, aka a sequence of characters that are enclosed in question makrs. Strings represent *Text* in python. it works using "double quotes" or 'single quotes'
# Python then displays the code as Hello, world!

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# The purpose of this markdown is to test out this copilot promt: Initial prompt to understand loops: Could you suggest a modification of the
# Python code for “Hello, world!” to demonstrate the concept of loops to a
# complete beginner in programming? Please explain the code step-by-step
# highlighting any key aspects.

# %%
# We want to print "Hello, world!" 5 times.

# range(5) gives us the numbers 0, 1, 2, 3, 4 (five numbers total)
for i in range(5):
    # On each loop, print the message and show which loop number we are on.
    print("Hello, world!", "Loop number:", i)
# Out:
# Hello, world! Loop number: 0
# Hello, world! Loop number: 1
# Hello, world! Loop number: 2
# Hello, world! Loop number: 3
# Hello, world! Loop number: 4

# %% [markdown]
# This markdown is for the following copilot promt:Initial prompt to understand how to import libraries that extend
# functionality: Could you suggest a modification of the Python code for “Hello,
# world!” to demonstrate the concept of importing libraries to a complete
# beginner in programming? Please explain the code step-by-step highlighting any
# key aspects.

# %%
# 1) Import useful libraries from Python's standard library
import random          # for random choices
from datetime import datetime  # for timestamps
import time            # for delays

# 2) A small list of greeting messages
greetings = [
    "Hello, world!",
    "Hi there, world!",
    "Greetings, world!",
    "Hey, world!",
    
]

# 3) Do a tiny countdown using time.sleep (just for fun!)
print("Starting in...")
for i in [3, 2, 1]:
    print(i)
    time.sleep(1)  # wait 1 second

# 4) Pick a random greeting
message = random.choice(greetings)

# 5) Get the current timestamp
now = datetime.now()  # the current date and time
timestamp = now.strftime("%Y-%m-%d %H:%M:%S")  # format it nicely

# 6) Print the final message with a timestamp
print(f"{timestamp} — {message}")
# Out:
# Starting in...
# 3
# 2
# 1
# 2025-12-11 13:42:03 — Hey, world!

# %% [markdown]
# This markdown is for looking at the results of the following promt put into copilot: Initial prompt to understand how to use operators in Python: Could you
# suggest a modification of the Python code for “Hello, world!” to demonstrate the
# concept of operators to a complete beginner in programming? Please explain the
# code step-by-step highlighting any key aspects. Include discussions about
# addition and multiplication between strings and numbers.

# %%
# 1) Build a greeting using concatenation
hello = "Hello, " + "world!"

# 2) Repeat the greeting using multiplication
repeated = (hello + " ") * 2  # adds a space, then repeats twice

# 3) Do some arithmetic with numbers
times = 3 + 2  # 5
total_chars = len(hello) * times  # multiply the length by times

# 4) Show the result using an f-string
print(repeated)
print(f"We plan to print the greeting {times} times.")
print(f"Each '{hello}' has {len(hello)} characters, so total chars would be {total_chars}.")
# Out:
# Hello, world! Hello, world!
# We plan to print the greeting 5 times.
# Each 'Hello, world!' has 13 characters, so total chars would be 65.

# %% [markdown]
# This is for the following code from this promt put into copilot: Initial prompt to understand how to use advanced concepts such as
# classes, objects, and methods (try one term at a time if it is too much to
# handle at once): Could you suggest a modification of the Python code for “Hello,
# world!” to demonstrate the concept of classes, objects and methods to a
# complete beginner in programming? Please explain the code step-by-step
# highlighting any key aspects.

# %%
class Greeter:
    def __init__(self, name="world"):
        self.name = name
        self.count = 0

    def say_hello(self):
        self.count += 1
        print(f"Hello, {self.name}!")

    def set_name(self, new_name):
        if isinstance(new_name, str) and new_name.strip():
            self.name = new_name.strip()
        else:
            print("Please provide a non-empty name.")

    def stats(self):
        print(f"Greeted {self.name} {self.count} time(s).")


# --- Run the demo ---
if __name__ == "__main__":
    g = Greeter()            # default: "world"
    g.say_hello()            # Hello, world!
    g.set_name("Reader")      # change name
    g.say_hello()            # Hello, Reader!
    g.say_hello()            # Hello, Reader!
    g.stats()                # Greeted Reader 3 time(s).
# Out:
# Hello, world!
# Hello, Reader!
# Hello, Reader!
# Greeted Reader 3 time(s).

# %% [markdown]
# This markdown is for experimenting with pseudocode using an everyday algorithm:
# 1.Wake up
# 2.Fill kettle
# 3. Make coffee
# 4. Make bed
# 5. Brush teeth
# 6. Get dressed

# %%
# Morning routine steps

def wake_up():
    print("Step 1: Wake up")

def fill_kettle():
    print("Step 2: Fill kettle")

def make_coffee():
    print("Step 3: Make coffee")

def make_bed():
    print("Step 4: Make bed")

def brush_teeth():
    print("Step 5: Brush teeth")

def get_dressed():
    print("Step 6: Get dressed")

# Main program
def morning_routine():
    wake_up()
    fill_kettle()
    make_coffee()
    make_bed()
    brush_teeth()
    get_dressed()

# Run the routine
morning_routine()
# Out:
# Step 1: Wake up
# Step 2: Fill kettle
# Step 3: Make coffee
# Step 4: Make bed
# Step 5: Brush teeth
# Step 6: Get dressed

# %% [markdown]
# The above is the code that copilot generated for the everyday algorithm, the code ran straight away and the output is clear and makes sense.

# %% [markdown]
# IPython.display

# %%
# Cell 1: Imports
from IPython.display import YouTubeVideo, display

# Cell 2: Choose your video ID or URL
VIDEO_ID = "uMzUB89uSxU"
PLAYER_WIDTH = 400
PLAYER_HEIGHT = 360
START_SECONDS = 1

# Cell 3: Display
display(YouTubeVideo(VIDEO_ID, width=PLAYER_WIDTH, height=PLAYER_HEIGHT, start=START_SECONDS))
